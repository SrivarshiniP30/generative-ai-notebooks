# %% [markdown]
# pdf file loading, chunking, encoding & embedding

# %%
from langchain_community.document_loaders import PyPDFLoader

loader=PyPDFLoader("data/chase_banking.pdf")
documents= loader.load()
print(documents)
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 19.5 (Macintosh)', 'creationdate': '2024-10-03T09:29:06-04:00', 'author': 'JPMorgan Chase Bank', 'keywords': 'Chase; total; checking; guide to your account; ada; (PDF)', 'moddate': '2024-10-07T09:59:35-04:00', 'subject': 'Chase Total Checking - A Guide To Your Account', 'title': 'Chase Total Checking - A Guide To Your Account (PDF)', 'trapped': '/Unknown', 'source': 'data/chase_banking.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1'}, page_content='HAVE QUESTIONS? CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT\n1\nCHASE TOTAL CHECKING\n®\nA GUIDE TO YOUR ACCOUNT †\nIt’s important that you understand how your Chase Total Checking account works. \nWe’ve created this Guide to explain the fees and some key terms of your personal account.\nMONTHLY \nSERVICE FEE*\nMonthly Service Fee $12\nWays to Avoid the \nMonthly Service Fee\n$0 Monthly Service Fee when you have any ONE  of the following during each \nmonthly statement period:\n•  Electronic deposits made into this account totaling $500 or more, such as \npayments from payroll providers or government benefit providers, by using \n(i) the ACH network, (ii) the Real Time Payment or FedNow SM network, or  \n(ii\ni) third party services that facilitate payments to your debit card using the \nVisa® or Mastercard® network\n• OR, a balance at the beginning of each day of $1,500 or more in this account\n•  OR, an average beginning day balance of $5,000 or more in any combination \nof this account and linked qualifying deposits 1/investments 2\nATM FEES\nNon-Chase ATM \n(Avoid these fees by \nusing a Chase ATM)\n$3 per withdrawal at a non-Chase ATM in the U.S. and the U.S. territories\n$5 per withdrawal at a non-Chase ATM outside the U.S. and the U.S. territories\nSurcharge Fees from the ATM owner/network still apply. U.S. territories include \nAmerican Samoa, Guam, the Northern Mariana Islands, Puerto Rico, and the \nU.S. Virgin Islands\nFees for using your account when you don’t have enough money in it or it’s already overdrawn\nOVERDRAFT FEES\nOverdraft:\nChase pays a \ntransaction \nduring our nightly \nprocessing \non a business \nday when your \naccount balance is \noverdrawn\n$34 Overdraft Fee per transaction during our nightly processing beginning with \nthe first transaction that overdraws your account balance by more than $50.\n• Maximum of 3 fees per business day (up to $102)\nWe won’t charge an Overdraft Fee:\n•  With Chase Overdraft Assist SM, if you’re overdrawn by $50 or less at the \nend of the business day OR if you’re overdrawn by more than $50 and you \nbring your account balance to overdrawn by $50 or less at the end of the \nnext business day (you have until 11 p.m. ET (8 p.m. PT) to make a deposit \nor transfer). Chase Overdraft Assist does not require enrollment and comes \nwith eligible Chase checking accounts\n• If your transaction is $5 or less\n•  If your debit card transaction was authorized when there was a sufficient \navailable balance in your account\n•  If your check or ACH is returned unpaid. However, we may charge an Overdraft \nFee if a previously returned check or ACH is presented again and paid\n• If your debit card transaction or ATM cash withdrawal request is declined\nYou can avoid overdrawing your account by making a deposit or transferring funds to cover the overdraft before the \nbusiness day ends and we start our nightly processing. Here are the cutoff times for some ways of making a deposit or \ntransferring funds from another Chase account:\n• At a branch before it closes\n• At an ATM before 11 p.m. Eastern Time (8 p.m. Pacific Time)\n• When transferring money on chase.com  or Chase Mobile® or using Zelle® before 11 p.m. Eastern Time (8 p.m. Pacific Time)\nIf you deposit a check, this assumes we do not place a hold and the check is not returned. Additional cutoff times apply to \nother tra ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

Rec_splitter= RecursiveCharacterTextSplitter(
    separators =["\n\n","\n","."," ",""],
    chunk_size=100,
    chunk_overlap=20,
    
)

# %%
chunks = []
for doc in documents:
    texts = Rec_splitter.split_text(doc.page_content)
    chunks.extend(texts)
    
for chunk in enumerate(chunks):
    print(chunk)
# Out:
# (0, 'HAVE QUESTIONS? CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (1, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (2, '1\nCHASE TOTAL CHECKING\n®\nA GUIDE TO YOUR ACCOUNT †')
# (3, 'It’s important that you understand how your Chase Total Checking account works.')
# (4, 'We’ve created this Guide to explain the fees and some key terms of your personal account.\nMONTHLY')
# (5, 'MONTHLY \nSERVICE FEE*\nMonthly Service Fee $12\nWays to Avoid the \nMonthly Service Fee')
# (6, 'Monthly Service Fee\n$0 Monthly Service Fee when you have any ONE  of the following during each')
# (7, 'monthly statement period:')
# (8, '•  Electronic deposits made into this account totaling $500 or more, such as')
# (9, 'payments from payroll providers or government benefit providers, by using')
# (10, '(i) the ACH network, (ii) the Real Time Payment or FedNow SM network, or  \n(ii')
# (11, '(ii\ni) third party services that facilitate payments to your debit card using the')
# (12, 'Visa® or Mastercard® network')
# (13, '• OR, a balance at the beginning of each day of $1,500 or more in this account')
# (14, '•  OR, an average beginning day balance of $5,000 or more in any combination')
# (15, 'of this account and linked qualifying deposits 1/investments 2\nATM FEES\nNon-Chase ATM')
# (16, 'Non-Chase ATM \n(Avoid these fees by \nusing a Chase ATM)')
# (17, 'using a Chase ATM)\n$3 per withdrawal at a non-Chase ATM in the U.S. and the U.S. territories')
# (18, '$5 per withdrawal at a non-Chase ATM outside the U.S. and the U.S. territories')
# (19, 'Surcharge Fees from the ATM owner/network still apply. U.S. territories include')
# (20, 'American Samoa, Guam, the Northern Mariana Islands, Puerto Rico, and the \nU.S. Virgin Islands')
# (21, 'Fees for using your account when you don’t have enough money in it or it’s already overdrawn')
# (22, 'OVERDRAFT FEES\nOverdraft:\nChase pays a \ntransaction \nduring our nightly \nprocessing \non a business')
# (23, 'on a business \nday when your \naccount balance is \noverdrawn')
# (24, 'overdrawn\n$34 Overdraft Fee per transaction during our nightly processing beginning with')
# (25, 'the first transaction that overdraws your account balance by more than $50.')
# (26, '• Maximum of 3 fees per business day (up to $102)\nWe won’t charge an Overdraft Fee:')
# (27, '•  With Chase Overdraft Assist SM, if you’re overdrawn by $50 or less at the')
# (28, 'end of the business day OR if you’re overdrawn by more than $50 and you')
# (29, 'bring your account balance to overdrawn by $50 or less at the end of the')
# (30, 'next business day (you have until 11 p.m. ET (8 p.m. PT) to make a deposit')
# (31, 'or transfer). Chase Overdraft Assist does not require enrollment and comes')
# (32, 'with eligible Chase checking accounts\n• If your transaction is $5 or less')
# (33, '•  If your debit card transaction was authorized when there was a sufficient')
# (34, 'available balance in your account')
# (35, '•  If your check or ACH is returned unpaid. However, we may charge an Overdraft')
# (36, 'Fee if a previously returned check or ACH is presented again and paid')
# (37, '• If your debit card transaction or ATM cash withdrawal request is declined')
# (38, 'You can avoid overdrawing your account by making a deposit or transferring funds to cover the')
# (39, 'funds to cover the overdraft before the')
# (40, 'business day ends and we start our nightly processing')
# (41, '. Here are the cutoff times for some ways of making a deposit or')
# (42, 'transferring funds from another Chase account:\n• At a branch before it closes')
# (43, '• At an ATM before 11 p.m. Eastern Time (8 p.m. Pacific Time)')
# (44, '• When transferring money on chase.com  or Chase Mobile® or using Zelle® before 11 p.m')
# (45, '.m. Eastern Time (8 p.m. Pacific Time)')
# (46, 'If you deposit a check, this assumes we do not place a hold and the check is not returned')
# (47, '. Additional cutoff times apply to')
# (48, 'other transfers, including transfers from non-Chase accounts. Please visit chase')
# (49, '. Please visit chase.com  or Chase Mobile for more information')
# (50, 'and service agreements.')
# (51, '† For the complete terms governing your account, please consult the Deposit Account Agreement')
# (52, '. The terms of the account, including any fees or features, may change.')
# (53, '*\t \tNew\tand\tconverted\tacco unts\twill\tnot\tbe\tchar ged\ta\tMonth ly\tServi ce\tFee\tfor\tat\tleas')
# (54, 'ce\tFee\tfor\tat\tleas t\tthe\tfirst\ttwo\tstat ement\tperi ods')
# (55, '.\tAfte r\tthat\tthe\tMont hly\tServi ce\tFee\twill\tappl y\tunles s\tyou\tmeet\tone\tof\tthe\tways\tto\tavoi')
# (56, 'd\tthe\tMont hly\tServi ce')
# (57, 'Fee each statement period (if applicable).')
# (58, '1  Qualifying personal deposits include Chase First Checking SM accounts, personal Chase savings')
# (59, 'Chase savings accounts (excluding Chase Premier Savings SM and Chase Private Client Savings SM),')
# (60, 'Client Savings SM), CDs, certain Chase Retirement CDs, and certain')
# (61, 'Chase Retirement Money Market Accounts.')
# (62, '2\t \tQualifying\tperso nal\tinvest ments\tinclude\tbalanc es\tin\tinvest ment\tand\tannuity\tproduc')
# (63, 'ts\toffered\tthroug h\tJPMor gan\tChase\t&\tCo')
# (64, '.\tand\tits\taffiliate s\tand\tagenci es.\tFor\tmost\tproduc ts,\twe\tuse\tdaily\tbalanc es\tto\tcalcu late\tthe')
# (65, 'average beginning day balance for such investment and annuity products')
# (66, '. Some third party providers report balances on a weekly, not daily, basis and we will use the most')
# (67, 'will use the most current balance reported')
# (68, '. Balances in 529 plans,')
# (69, 'don')
# (70, 'or-advised funds, and certain retirement plan investment accounts do not qualify')
# (71, '. Investment products and related services are only available in English.')
# (72, 'J.P.\tMorgan\tWeal th\tMana gement\tis\ta\tbusi ness\tof\tJPMo rgan\tChas e\t&\tCo')
# (73, '.,\twhic h\toffer s\tinve stment\tprod ucts\tand\tservi ces\tthro ugh\tJ.P')
# (74, '.P. Morgan Securities LLC \t(JPMS),\ta\tregistered\tbrok er-dealer\tand\tinve stment\tadvise r,')
# (75, 'member FINRA and SIPC. Insurance products are made available through Chase Insurance Agency, Inc')
# (76, '. (CIA), a licensed insurance agency, doing business as Chase Insurance Agency Services, Inc')
# (77, '. in Florida. Certain custody')
# (78, 'and\tother\tservices\tare\tprovided\tby\tJPMorgan\tChase\tBank,\tN.A.\t(JPMCB)')
# (79, '.\tJPMS,\tCIA\tand\tJPMCB\tare\taffiliated\tcompanies\tunder\tthe\tcommon\tcontrol\tof\tJPMorgan\tChase\t&\tCo')
# (80, '.\tProducts\tnot\tavailable\tin\tall\tstates.')
# (81, 'INVESTMENT AND INSURANCE PRODUCTS:')
# (82, '• NOT A DEPOSIT • NOT FDIC INSURED • NOT INSURED BY ANY FEDERAL GOVERNMENT AGENCY • NO BANK')
# (83, 'AGENCY • NO BANK GUARANTEE • MAY LOSE VALUE')
# (84, 'HAVE QUESTIONS?  CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (85, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (86, 'CHASE TOTAL CHECKING\n®\n2\nCHASE DEBIT \nC\nARD COVERAGE SM \nA\nND FEES 3\n(Please visit \nw')
# (87, '(Please visit \nw\nww.chase.com/checking/\ndebit-card-coverage  \nf\nor additional details.)')
# (88, 'Chase Debit Card Coverage: You can choose how we treat your everyday (not recurring) debit card')
# (89, 'transactions when you don’t have enough money available. Please note: Regardless of which option')
# (90, 'you choose for Chase Debit Card Coverage, you may also want to sign up for Overdraft Protection if')
# (91, 'Protection if you')
# (92, 'are eligible. Please visit www.chase')
# (93, '.chase.com/OverdraftProtection  for more details, including terms and')
# (94, 'conditions.\nOPTION #1 (YES): You ask us to add Chase Debit Card Coverage')
# (95, 'This means you want Chase to authorize and pay your everyday debit card transactions, at our')
# (96, 'discretion, when you don’t have enough money to cover a transaction (this includes available funds')
# (97, 'available funds in')
# (98, 'your linked Overdraft Protection account, if enrolled). Overdraft Fees may apply.\nOverdraft')
# (99, 'Overdraft\n$34 Overdraft Fee per transaction during our nightly processing beginning with')
# (100, 'the first transaction that overdraws your account balance by more than $50.')
# (101, '• Maximum of 3 fees per business day (up to $102)\nWe won’t charge an Overdraft Fee:')
# (102, '•  With Chase Overdraft Assist, if you’re overdrawn by $50 or less at the end')
# (103, 'of the business day OR if you’re overdrawn by more than $50 and you bring')
# (104, 'your account balance to overdrawn by $50 or less at the end of the next')
# (105, 'business day (you have until 11 p.m. ET (8 p.m. PT) to make a deposit or')
# (106, 'transfer). Chase Overdraft Assist does not require enrollment and comes')
# (107, 'with eligible Chase checking accounts\n• If your transaction is $5 or less')
# (108, '•  If your debit card transaction was authorized when there was a sufficient')
# (109, 'available balance in your account')
# (110, '•  If your check or ACH is returned unpaid. However, we may charge an Overdraft')
# (111, 'Fee if a previously returned check or ACH is presented again and paid')
# (112, '• If your debit card transaction or ATM cash withdrawal request is declined')
# (113, 'OPTION #2  (NO ):  No Chase Debit Card Coverage (If you don’t choose an option when you')
# (114, 'open your account, Option #2 (No) is automatically selected for you)')
# (115, 'This means you do not want Chase to authorize and pay your everyday debit card transactions when')
# (116, 'you don’t have enough money to cover a transaction (this includes available funds in your linked')
# (117, 'Overdraft Protection account, if enrolled)')
# (118, '. Since everyday debit card transactions will be declined')
# (119, 'when there is not enough money available, you won’t be charged an Overdraft Fee for everyday debit')
# (120, 'card transactions.')
# (121, 'You can avoid overdrawing your account by making a deposit or transferring funds to cover the')
# (122, 'funds to cover the overdraft before the')
# (123, 'business day ends and we start our nightly processing')
# (124, '. Here are the cutoff times for some ways of making a deposit or')
# (125, 'transferring funds from another Chase account:\n• At a branch before it closes')
# (126, '• At an ATM before 11 p.m. Eastern Time (8 p.m. Pacific Time)')
# (127, '• When transferring money on chase.com  or Chase Mobile or using Zelle before 11 p.m')
# (128, '.m. Eastern Time (8 p.m. Pacific Time)')
# (129, 'If you deposit a check, this assumes we do not place a hold and the check is not returned')
# (130, '. Additional cutoff times apply to')
# (131, 'other transfers, including transfers from non-Chase accounts. Please visit chase')
# (132, '. Please visit chase.com  or Chase Mobile for more information')
# (133, 'and service agreements.\nSee the next page for other fees that may apply.')
# (134, '3  Important details about your Chase Debit Card Coverage:  An everyday debit card transaction is a')
# (135, 'transaction is a one-time purchase or payment, such as groceries, gasoline or dining out, and')
# (136, 'or dining out, and includes PIN and non-PIN point-of-sale')
# (137, 'transactions')
# (138, '.\tW hether \to r\tn ot\tyo u\tch oose\tt o\th ave\tyo ur\te veryday\td ebit\tc ard\tt ransactions\tc overed\tw')
# (139, 'overed\tw ill\tn ot\ta ffect\tt he\tw ay\tw e\tt reat\tyo ur\tr ecurring\td ebit\tc ard\tt ransactions\t( such\ta')
# (140, 'such\ta s\tm onthly\tm ovie\tr entals,\tg ym\tm emberships\to r\ts ubscriptions)')
# (141, 'when\tyou\tdon’t\thave\tenough\tmoney\tin\tyour\taccount\tto\tcover\tthe\ttransactions')
# (142, '.\tWe\tmay,\tat\tour\tdiscretion,\tauthorize\tand\tpay\ta\trecurring\tdebit\tcard\ttransaction\tthat\tcauses\tan\tove')
# (143, 'n\tthat\tcauses\tan\toverdraft\tand\tcharge\tan\tOverdraft\tFee')
# (144, '.')
# (145, 'HAVE QUESTIONS?  CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (146, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (147, 'CHASE TOTAL CHECKING\n®\n3\nHOW \nDE\nPOSITS AND \nWITHDRAWALS \nWORK\nThe Order in \nWh\nich Withdrawals \nan')
# (148, 'ich Withdrawals \nan\nd Deposits \nAr\ne Posted During \nOur Nightly \nProcessing')
# (149, 'Processing\nPosting order is the order in which we apply deposits and withdrawals to your')
# (150, 'account. We provide you with visibility into how transactions are posted and in')
# (151, 'what order to help you better manage your account.')
# (152, 'When we transition from one business day to the next business day we post')
# (153, 'transactions to and from your account during our nightly processing. The')
# (154, 'order in which we generally post transactions during nightly processing for \neach business day is:')
# (155, '•  First, we make any previous day adjustments, and add deposits to your\naccount.')
# (156, 'account.\n•  Second, we subtract transactions in chronological order by using the date')
# (157, 'and time of when the transaction was authorized or shown as pending.')
# (158, 'This includes ATM and Chase banker withdrawals, transfers and payments;')
# (159, 'automatic payments; chase.com  or Chase Mobile online transactions; checks')
# (160, 'drawn on your account; debit card transactions; wire transfers; and real time')
# (161, 'payments. If multiple transactions have the same date and time, then they')
# (162, 'are posted in high to low dollar order.')
# (163, '-  There are some instances where we do not have the time of the transaction')
# (164, 'therefore we post at the end of the day the transaction occurred:')
# (165, '• We are unable to show the transaction as pending; or')
# (166, '•  We don’t receive an authorization request from the merchant but the')
# (167, 'transaction is presented for payment.')
# (168, '•  Third, there are some transactions that we cannot process automatically or')
# (169, 'until we’ve completed posting of your chronological transactions. This includes')
# (170, 'Overdraft Protection transfers or transfers to maintain target balances in other')
# (171, 'accounts. We subtract these remaining transactions in high to low dollar order.')
# (172, '• Finally, fees are assessed last.')
# (173, 'If you review your account during the day, you will see that we show')
# (174, 'some transactions as “pending.” For details, refer to the section “Pending”')
# (175, 'transactions in the Deposit Account Agreement . These transactions impact')
# (176, 'your available balance, but have not yet posted to your account and do not')
# (177, 'guarantee that we will pay these transactions to your account if you have a')
# (178, 'negative balance at that time. We may still return a transaction unpaid if your')
# (179, 'balance has insufficient funds during that business day’s nightly processing,')
# (180, 'even if it had been displayed as a “pending” transaction on a positive balance')
# (181, 'during the day. If a transaction that you made or authorized does not display')
# (182, 'as “pending,” you are still responsible for it and it may still be posted against')
# (183, 'your account during nightly processing.\nWhen Your Deposits \nAre Available \n(S\nee Funds')
# (184, '(S\nee Funds \nAvailability Policy in \nthe Deposit Account \nAgreement for \ndetails)')
# (185, 'details)\n• Cash deposit – Same business day\n• Direct deposit/wire transfer – Same business day')
# (186, '• Check deposit – Usually the next business day, but sometimes longer:')
# (187, '-  If we place a longer hold on a check, the first $225 will be available by the\nnext business day')
# (188, 'next business day\n-  The date your deposit is expected to be available will be displayed on your')
# (189, 'receipt\n-  In some situations, we may notify you at the time or after your deposit is')
# (190, 'made that your funds (including the first $225) will not be available for up to\nseven business days')
# (191, 'seven business days\nA “business day” is a non-holiday weekday. The cutoff times listed in the')
# (192, 'section above will determine the “business day” for your deposit.\nOTHER ATM \nAN\nD DEBIT CARD \nFEES')
# (193, 'D DEBIT CARD \nFEES\nCard Replacement – Rush Request: You request express shipping of a')
# (194, 'replacement debit or ATM card\n \n(A\nvoid this fee by requesting standard shipping)\n$5 p')
# (195, '$5 p\ner card, upon request\nNon-ATM Cash: You use your Chase Debit Card to withdraw cash from')
# (196, 'another financial institution (excluding ATMs)\n3%\n o\nf the dollar amount of \nthe transaction OR')
# (197, '$5, w\nhichever is greater\nForeign Exchange Rate Adjustment: You make card purchases,  \nno')
# (198, 'no\nn-ATM cash transactions or ATM withdrawals in a currency other \nthan U.S. dollars')
# (199, 'than U.S. dollars\n3% o f withdrawal amount \nafter conversion to U.S. \ndollars. For additional')
# (200, 'information on foreign \nexchange rates, refer to the \nDeposit Account Agreement')
# (201, 'See the next page for other fees that may apply.')
# (202, 'CHASE TOTAL CHECKING\n®\n4\nWIRE TRANSFER \nFEES4, 5')
# (203, 'FEES4, 5\nDomestic and International Incoming Wire: A wire transfer is \ndeposited into your account')
# (204, '$15 per transfer OR  \n$0 i\nf the transfer was \noriginally sent with the help')
# (205, 'of a Chase banker or using \nchase.com or Chase Mobile')
# (206, 'Domestic Wire: A banker helps you to send a wire to a bank account \nwithin the U.S. $35')
# (207, 'per transfer\nOnline Domestic Wire: You use chase.com or Chase Mobile to send a')
# (208, 'wire from your account to a bank account within the U.S. $25 per transfer')
# (209, 'Consumer USD/FX International Wire: A banker helps you send a wire')
# (210, 'to a bank account outside the U.S. in either U.S. dollars (USD) or foreign \ncurrency (FX)\n$50')
# (211, 'currency (FX)\n$50\n \nper transfer\nConsumer Online USD International Wire:  You use chase.com or')
# (212, 'Chase Mobile to send a wire from your account to a bank account')
# (213, 'outside the U.S. in U.S. dollars (USD)\n$40\n \nper transfer')
# (214, '$40\n \nper transfer\nConsumer Online FX International Wire:  You use chase.com or Chase')
# (215, 'Mobile to send a wire from your account to a bank account outside the')
# (216, 'U.S. in foreign currency (FX)\n$5\n per transfer OR  \n$0 p er transfer if the')
# (217, 'amount is equal to $5,000 \nUSD or more')
# (218, 'For wire transfers you send or we receive in a foreign currency, the exchange rate is determined by')
# (219, 'is determined by us in our sole discretion')
# (220, 'and includes a spread, which we may make a commission from when completing the foreign currency')
# (221, 'foreign currency exchange')
# (222, '. You should')
# (223, 'expect that these foreign exchange rates will be less favorable than rates quoted online or in')
# (224, 'quoted online or in publications')
# (225, '. For additional')
# (226, 'information on these rates, refer to the Deposit Account Agreement  and Wire Transfers Agreements.')
# (227, 'OTHER FEES\nStop Payment: You contact us and a banker places your stop payment')
# (228, 'request on a check or ACH $30\n p er request')
# (229, 'p er request\nOnline or Automated Phone Stop Payment: You use chase.com , Chase')
# (230, 'Mobile or our automated phone system to place a stop payment on a')
# (231, 'check. Only some types of stop payments are available\n$25\n p\ner request')
# (232, '$25\n p\ner request\nOrder for Checks or Supplies: An order of personal checks, deposit')
# (233, 'slips or other banking supplies\nVaries (based on items \nordered)')
# (234, 'ordered)\nCounter Check: A blank page of 3 personal checks we print upon your')
# (235, 'request at a branch $3 per page\nMoney Order: A check issued by you, purchased at a branch, for an')
# (236, 'amount up to $1,000 $5\n p\ner check')
# (237, 'p\ner check\nCashier’s Check: A check issued by the bank, purchased at a branch,')
# (238, 'for any amount and to a payee you designate $10 per check')
# (239, 'Legal Processing: Processing of any garnishment, tax levy, or other')
# (240, 'court administrative order against your accounts, whether or not the \nfunds are actually paid')
# (241, 'Up to $100 per order\nSAFE DEPOSIT BOX \nANNUAL RENT')
# (242, 'ANNUAL RENT\nAssessed annually at lease renewal. We currently do not rent new Safe \nDeposit Boxes')
# (243, 'Deposit Boxes\nVaries by size and location, \nincludes sales tax where')
# (244, 'applicable (disclosed on your \nannual invoice)')
# (245, '4\t \tFinancial\tinstitutions\tmay\tdedu ct\tpro cessing\tfee s\tand/ or\tcharg es\tfro m\tthe\tamou')
# (246, 'es\tfro m\tthe\tamou nt\tof\tthe\tinco ming\tor\tout going\twire\ttran sfers,\tinclu ding\ton\tretu')
# (247, 'ding\ton\tretu rned\twire\ttran sfers')
# (248, '.\tAny\tdedu ctions\ttake n\tby\tus,\tand\tour\taffili ates,\tmay\tinclu de')
# (249, 'processing fees charged by Chase.')
# (250, '5\t \tWe\tmay\tuse\tan y\tfu nds\ttr ansfer\tsy stem\twe\tbe lieve\tre asonable\tto\tco mplete\tyo ur\tre')
# (251, 'mplete\tyo ur\tre quest,\tre gardless\tof\tan y\tin structions\tyo u\tmi ght\tgi ve\tus')
# (252, '.\tIf\twe\tal so\tar e\tth e\tre cipient’s\tba nk,\twe\tma y\tco mplete\tyo ur\tre quest\tus ing\tan\tin ternal')
# (253, 'transfer, and assess a wire transfer fee.')
# (254, 'HAVE QUESTIONS? CALL US AT 1-800-935-9935 (WE ACCEPT OPERATOR RELAY CALLS)  • WANT MORE INFO?  SEE')
# (255, 'MORE INFO?  SEE THE DEPOSIT ACCOUNT AGREEMENT')
# (256, 'JPMorgan Chase Bank, N.A. Member FDIC\n© 2024 JPMorgan Chase & Co.\nEffective 11/17/2024')
# (257, 'FEETABLE-TOTAL-1124-ONLN')

# %% [markdown]
# embedding-->

# %%
embedding_name="sentence-transformers/all-mpnet-base-v2"

# %%
from langchain.embeddings import HuggingFaceEmbeddings

embedding_model= HuggingFaceEmbeddings(model_name=embedding_name)
# Out:
# c:\GenAI\genenv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\sriva\.cache\huggingface\hub\models--sentence-transformers--all-mpnet-base-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`

# %% [markdown]
# |
# v  Sentence or query embedding

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("all-MiniLM-L6-v2")
sentence = "i went to school"
embedding = model.encode(sentence)

print("embedding vector :", embedding)
print("shape: ",embedding.shape)
# Out:
# embedding vector : [ 2.41229795e-02  3.27841789e-02  4.21684124e-02  7.06386939e-02
#   3.42750363e-02 -3.96274291e-02  5.35857156e-02  7.00612813e-02
#   3.34660499e-03  6.70948997e-02  6.90140650e-02 -1.26070296e-02
#  -8.47209594e-04  5.18247634e-02  3.85788046e-02 -3.00673675e-02
#  -3.65992188e-02 -1.05373971e-02 -9.22920927e-02 -1.21456884e-01
#  -1.15022920e-01  6.14141598e-02 -5.66411465e-02  6.07810654e-02
#   1.28097273e-02  1.24614246e-01 -1.01891989e-02 -6.94193505e-03
#  -1.79036763e-02 -1.01018585e-02 -9.51918066e-02  5.25323907e-03
#  -7.84068257e-02 -2.60638427e-02  6.65851636e-03  1.35533856e-02
#   9.84113887e-02  4.83963918e-03  4.49659787e-02  5.38215600e-02
#  -2.05139746e-03 -4.51924428e-02  4.19216491e-02  3.31504866e-02
#   4.70329151e-02 -2.65491046e-02  4.80113644e-03 -2.82632355e-02
#   8.43241066e-02  1.72496680e-02 -3.93109536e-03 -1.19600985e-02
#  -2.64469553e-02 -3.22561599e-02 -2.63440087e-02  7.38904104e-02
#  -6.11144714e-02  4.65779100e-04  3.34931649e-02 -1.04494179e-02
#  -1.23338820e-02 -3.22112255e-02 -1.05491914e-02  4.18204628e-02
#   2.65529957e-02  6.96662590e-02  5.64203737e-03  1.89987966e-03
#   4.50669974e-02  7.19905943e-02  1.35627319e-03  2.78119203e-02
#  -2.87938435e-02  3.81965935e-02  6.71630725e-02  6.09460007e-03
#   6.15289509e-02  2.24917680e-02  1.25062123e-01 -6.83687031e-02
#  -2.13291869e-02 -4.01235856e-02 -4.34411243e-02  2.12461152e-03
